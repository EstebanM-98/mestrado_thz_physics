# %%
import os
os.chdir('..')  # Mueve el directorio de trabajo un nivel arriba

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from scipy.signal import find_peaks
import scipy.signal.windows as win
import scipy as sp
import warnings
import re
from ipywidgets import interact,widgets
from scipy.optimize import curve_fit
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfc
from scipy.misc import derivative
from matplotlib.colors import hsv_to_rgb
import warnings
from functions_master import *
from glob import glob
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.gridspec as gridspec
import matplotlib.cm as cm
from matplotlib.colors import Normalize

# Suprimir FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)
c = 0.299792458 # speed of light mm/ps

# %% [markdown]
# # Reference.
#
# 9e-10

# %%
ruta_actual = os.getcwd()
ruta_actual
# Out:
# 'c:\\Users\\esmaru\\Desktop\\Esteban\\repos\\mestrado_thz_physics'

# %%
# sample1_ang_csv = os.path.join(ruta_actual,"sample1_ang.csv")
carpeta_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\sample1_ang")
carpeta_ref_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\reference1")
archivos_dat_ref = glob(os.path.join(os.path.join(carpeta_ref_sample1,'carpeta1'), '*.dat'))
archivos_dat_samp = glob(os.path.join(os.path.join(carpeta_sample1,'carpeta1'), '*.dat'))

# Elimina cada archivo
for archivo in archivos_dat_samp:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

for archivo in archivos_dat_ref:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

convert_dats(carpeta_ref_sample1,0)
convert_dats(carpeta_sample1,3)

# Filtrar y ordenar los archivos por la temperatura
archivos_dat_ref = sorted(
    archivos_dat_ref,
    key=lambda x: extraer_temperatura(x)
)

archivos_dat_samp = sorted(
    archivos_dat_samp,
    key=lambda x: extraer_temperatura(x)
)
# Out:
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_100.3K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_103.3K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_106.2K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_109.0K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_11.9K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_111.9K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_114.85K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_118.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_121.4K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_124.35K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_127.1K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_129.85K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_133.65K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_136.4K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_139.1K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_142.85K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_145.6K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_148.15K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_151.8K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_19.9K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_25.2K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_29.2K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_32.8K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_36.0K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_39.0K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_43.25K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_47.3K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_49.8K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_52.3K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_54.7K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_58.2K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_61.6K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_63.8K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_67.0K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_70.2K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_73.3K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_76.4K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_79.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_82.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_85.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_88.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_91.5K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_94.4K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_97.35K.dat eliminado.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\reference1\carpeta1\Average_294.4K.dat eliminado.
# ['20250611-144959__Esteban__THZ57.5-62.5__PMP0__S2207L__6RH__294.4K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250611-145300__Esteban__THZ57.5-62.5__PMP0__S2207L__6RH__294.4K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250611-145601__Esteban__THZ57.5-62.5__PMP0__S2207L__6RH__294.4K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat']
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\reference1\carpeta1\Average_294.4K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\reference1\carpeta1.
# ['20250612-113945__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__11.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-114246__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__19.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-114547__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__25.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-114848__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__29.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-115149__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__32.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-115451__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__36.0K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-115753__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__39.0K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-120054__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__41.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-120355__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__44.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-120657__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__47.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-120959__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__49.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-121301__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__52.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-121603__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__54.7K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-121905__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__57.1K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-122206__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__59.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-122508__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__61.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-122810__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__63.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-123111__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__65.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-123412__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__68.1K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-123713__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__70.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-124015__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__72.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-124316__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__74.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-124617__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__76.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-124918__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__78.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-125220__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__80.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-125522__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__82.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-125823__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__84.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.dat', '20250612-130125__Eduardo__THZ58.5-63.5__PMP0__S2207L__3RH__86.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient135-HePumpOFF-100ms.d ...
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_11.9K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_19.9K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_25.2K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_29.2K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_32.8K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_36.0K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_39.0K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_43.25K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_47.3K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_49.8K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_52.3K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_54.7K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_58.2K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_61.6K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_63.8K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_67.0K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_70.2K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_73.3K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_76.4K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_79.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_82.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_85.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_88.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_91.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_94.4K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_97.35K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_100.3K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_103.3K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_106.2K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_109.0K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_111.9K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_114.85K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_118.5K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_121.4K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_124.35K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_127.1K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_129.85K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_133.65K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_136.4K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_139.1K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_142.85K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_145.6K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_148.15K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.
# Archivo c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1\Average_151.8K.dat generado en c:\Users\esmaru\Desktop\Esteban\repos\mestrado_thz_physics\EuZn2P2\src\sample1_ang\carpeta1.

# %% [markdown]
# # FULL DATA

# %%
from matplotlib import pyplot as plt
from matplotlib import gridspec
from ipywidgets import interact, FloatSlider
import numpy as np
import pandas as pd
import scipy as sp

def anim2(left, right_sample, right_subs, index, desv, d):
    right_ref = right_subs
    N = 2**15

    f = plt.figure(figsize=(10, 8), dpi=200)  # Aumenté el tamaño para 3 subplots

    # Grid: 2 filas, 2 columnas (la última celda ocupará ambas columnas)
    gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

    # Subgráficos
    ax1 = plt.subplot(gs[0, 0])  # Señales temporales (original)
    ax2 = plt.subplot(gs[0, 1])  # FFTs (nuevo)
    # ax3 = plt.subplot(gs[1, :])  # Absorción (ocupa toda la fila inferior)

    # Ruta del archivo de señal y de referencia
    path_signal = archivos_dat_samp[int(index)]
    path_ref = archivos_dat_ref[0]

    x, y = getFilterdata(path_signal,right_sample,left)
    x_ref, y_ref = getFilterdata(path_ref,right_ref,left)

    # Aplicar ventana
    y_subs= pd.Series(y_ref)
    y_signal= pd.Series(y)

    val = 2  # Desplazamiento para visualización

    # Señales en dominio temporal (subplot 1)
    ax1.plot(x_ref,y_ref / max(y_ref), 'r', label='Ref')
    # ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val,'b', label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title("Time Domain Signals")
    ax1.legend(loc='lower right')

    # Dominio de frecuencia
    nu = sp.fft.fftfreq(N, 1/30)
    k = 15
    nu = nu[1:len(nu)//k]

    # Aplicar Fourier y truncar
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)+1]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)+1]

    # Máscara de frecuencia
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)
    nu_filtradas = nu[mask]
    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]

    # Subplot 2: FFTs
    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2/np.abs(max(np.abs(fft_y_signal_ventaneada)**2)),'b', label='Sample FFT')
    ax2.plot(nu_filtradas, np.abs(fft_y_subs_ventaneada)**2/np.abs(max(np.abs(fft_y_subs_ventaneada)**2)),'r', label='Reference FFT')
    ax2.set_title("Frequency Domain")
    ax2.set_ylabel("$|FFT|^{2}$")
    ax2.set_xlabel(r"$\nu$ (THz)")
    ax2.legend()

    # Transmitancia y fase
    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase / 30)
    
    # # Subplot 3: Absorción (ocupa toda la fila inferior)
    # ax3.plot(nu_filtradas, -2 / d * np.log(abs(T)),'b')
    # ax3.set_ylabel(r"$\alpha$")
    # ax3.set_xlabel(r"$\nu$ (THz)")
    # ax3.set_title("Absorption Spectrum")
    # # ax3.set_yscale('log')  # Descomenta si quieres escala logarítmica

    # plt.tight_layout()

# Interfaz interactiva (sin cambios)
opc = dict(continuous_update=False, readout_format=".3f")
interact(anim2,       
    left=FloatSlider(min=380, max=423, value=394.9, step=0.1, **opc),
    right_sample=FloatSlider(min=380, max=423, value=417.9, step=0.1, **opc),
    right_subs=FloatSlider(min=380, max=423, value=417.9, step=0.1, **opc),
    index=FloatSlider(min=0, max=len(archivos_dat_samp) - 1, value=0, step=1, **opc),
    desv=FloatSlider(min=0, max=1000, value=190.324, step=0.001, **opc),
    d=FloatSlider(min=0.01, max=1, value=0.627, step=0.01, **opc)
)
# Out:
# interactive(children=(FloatSlider(value=394.9, continuous_update=False, description='left', max=423.0, min=380…
# <function __main__.anim2(left, right_sample, right_subs, index, desv, d)>

# %%
import matplotlib.animation as animation
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from colorsys import hsv_to_rgb
import matplotlib.cm as cm
from matplotlib.colors import Normalize


def create_frame(index, left, right_sample, right_subs, desv, d, axes, norm, cmap):
    ax1, ax2 = axes

    # Limpiar los ejes en lugar de fig.clear()
    for ax in axes:
        ax.clear()

    path_signal = archivos_dat_samp[int(index)]
    temp = extraer_temperatura(path_signal)
    color = cmap(norm(temp)) if temp is not None else 'blue'
    path_ref = archivos_dat_ref[0]

    N = 2**15
    params_window1 = ['flattop']

    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1)

    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2

    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'k', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val, color=color, label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title(f"T = {temp} K" if temp is not None else "Temperatura no disponible")
    ax1.legend(loc='lower right')

    k = 15
    nu = sp.fft.fftfreq(N, 1 / 30)
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

    nu = nu[1:len(nu)//k]
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)

    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
    nu_filtradas = nu[mask]

    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase * 1 / 30)

    T_exp = abs(T)
    phi_exp = np.unwrap(np.angle(T))

    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2, color=color)
    
    ax2.set_ylabel(r"$|FFT|^2$")
    # ax2.set_yscale('log')

def generate_gif():
    temps = []
    for path in archivos_dat_samp:
        temp = extraer_temperatura(path)
        if temp is not None:
            temps.append(temp)

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    left = 394.9
    right_sample = 417.9
    right_subs = 417.9
    desv = 190.324
    d = 0.627

    fig = plt.figure(figsize=(8, 4), dpi=200)
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])
    ax1 = plt.subplot(gs[0, 0])
    ax2 = plt.subplot(gs[0, 1])

  
    axes = [ax1, ax2]

    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    def animate(i):
        create_frame(i, left, right_sample, right_subs, desv, d, axes, norm, cmap)
        return axes
    carpeta = os.getcwd()
    ruta_guardado = os.path.join(carpeta, 'animacion_datos135_gaus.gif')
    ani = animation.FuncAnimation(fig, animate, frames=len(archivos_dat_samp), interval=400, blit=False)
    ani.save(ruta_guardado, writer=animation.PillowWriter(fps=2), dpi=200)
    plt.close()

# Ejecutar
generate_gif()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from matplotlib import cm
from matplotlib.colors import Normalize
import os

def plot_all_samples(left, right_sample, right_subs, desv, d, val_offset_signal=2, val_offset_kappa=0.03):
    temps = [extraer_temperatura(p) for p in archivos_dat_samp if extraer_temperatura(p) is not None][::-1]

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    N = 2**15
    params_window1 = ['flattop']
    fig, (ax1, ax4) = plt.subplots(1, 2, figsize=(8, 8), dpi=200)

    # ax1.set_title("Señal ventaneada + ventana (todas las muestras)")
    ax1.set_ylabel("Normalized field + offset")
    ax1.set_xlabel("Time (arb. u.)")

    # ax4.set_title(r"Coeficiente de extinción $\kappa$ (todas las muestras)")
    ax4.set_xlabel(r"$\nu$ (THz)")
    ax4.set_ylabel(r"$|FFT|^{2}$ (arb. u.)")

    # Antes del bucle, creamos listas para almacenar los máximos
    max1_freqs = []
    max1_values = []
    max2_freqs = []
    max2_values = []

    for index, path_signal in enumerate(archivos_dat_samp):
        temp = temps[index]
        color = cmap(norm(temp)) if temp is not None else 'blue'
        path_ref = archivos_dat_ref[0]

        phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
            path_signal, path_ref, left, right_sample, right_subs, params_window1)

        y_subs_ventana = pd.Series(y_substrate_padding * ventana)
        y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

        offset_signal = val_offset_signal * index

        ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + offset_signal, color=color, label=f'{temp:.1f} K')

        # FFT y kappa
        k = 15
        nu = sp.fft.fftfreq(N, 1 / 30)
        fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
        fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

        nu = nu[1:len(nu)//k]
        xmin, xmax = 0.3, 1.0
        mask = (nu >= xmin) & (nu <= xmax)

        fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
        fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
        nu_filtradas = nu[mask]

        val_offset_kappa = 0.8
        offset_kappa = val_offset_kappa * index
        
        normalized_fft = np.abs(fft_y_signal_ventaneada)**2/np.max(np.abs(fft_y_signal_ventaneada)**2) + offset_kappa
        
        ax4.plot(nu_filtradas, normalized_fft, color=color, label=f'{temp:.1f} K')
        
        max1_idx = np.argmax(normalized_fft)
        max1_freq = nu_filtradas[max1_idx]
        max1_val = normalized_fft[max1_idx]
                
            # Segundo máximo (entre 0.7 y 0.9 THz)
        mask_second_peak = (nu_filtradas >= 0.8) & (nu_filtradas <= 0.9)
        if np.any(mask_second_peak):  # Verificamos que haya datos en este rango
            second_peak_region = normalized_fft[mask_second_peak]
            second_peak_nu = nu_filtradas[mask_second_peak]
            max2_idx = np.argmax(second_peak_region)
            max2_freq = second_peak_nu[max2_idx]
            max2_val = second_peak_region[max2_idx]
        else:
            max2_freq, max2_val = np.nan, np.nan
        
        # Guardamos los máximos
        max1_freqs.append(max1_freq)
        max1_values.append(max1_val)
        max2_freqs.append(max2_freq)
        max2_values.append(max2_val)
        
        # Graficamos ambos puntos máximos
        ax4.scatter(max1_freq, max1_val, color='black', edgecolors=color, s=50, zorder=5)
        if not np.isnan(max2_freq):  # Solo graficar si existe el segundo máximo
            ax4.scatter(max2_freq, max2_val, color='white', edgecolors=color, s=50, zorder=5, marker='s')
        
        print(temp)
        # Después del bucle, unimos los puntos máximos con líneas
    ax4.plot(max1_freqs, max1_values, 'k--', linewidth=1, alpha=0.5, label='1er máximo')
    if any(not np.isnan(f) for f in max2_freqs):  # Solo graficar si hay segundos máximos
        ax4.plot(max2_freqs, max2_values, 'k:', linewidth=1, alpha=0.5, label='2do máximo')
    ax1.legend(loc='upper left', fontsize='small')
    # ax4.legend(loc='upper left', fontsize='small')

    # Barra de temperatura al costado
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    # plt.show()

        # Crear nueva figura para frecuencia vs temperatura
    fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(4, 8), dpi=200)

    # Graficar primer máximo (principal)
    ax1.scatter(temps, max1_freqs, c=temps, cmap='coolwarm', 
                edgecolors='k', s=80, label='Main peak', zorder=3)
    ax1.legend(loc='upper left', fontsize='small')
    ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)

    # Graficar segundo máximo (secundario, solo si existen valores válidos)
    valid_max2 = [(t, f) for t, f in zip(temps, max2_freqs) if not np.isnan(f)]
    if valid_max2:
        temps_max2, freqs_max2 = zip(*valid_max2)
        ax2.scatter(temps_max2, freqs_max2, c=temps_max2, cmap='coolwarm', 
                    edgecolors='k', s=80, marker='s', label='Secondary peak', zorder=3)
        ax2.set_xlabel('Temperature (K)')
        ax2.legend(loc='upper left', fontsize='small')
        ax2.set_ylabel('Frecuency (THz)')
    if valid_max2:
        ax2.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Añadir líneas de tendencia (opcional)
    # ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)
    # if valid_max2:
    #     ax1.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Ajustes estéticos
    # ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel('Frecuency (THz)')
    # ax1.title('Frecuencia de máximos vs Temperatura', fontsize=14)
    # ax1.grid(True, alpha=0.3)


# Ejecutar la función
plot_all_samples(left=394.9, right_sample=417.9, right_subs=417.9, desv=190.324, d=0.627)
# Out:
# 294.4
# 276.2
# 258.4
# 240.5
# 222.1
# 203.4
# 184.4
# 164.7
# 144.6
# 123.7
# 101.3
# 76.1
# 40.6
# 16.4

# %% [markdown]
# # Sample2

# %%
ruta_actual = os.getcwd()

# sample1_ang_csv = os.path.join(ruta_actual,"sample1_ang.csv")
carpeta_sample2 = os.path.join(ruta_actual,"src\\sample2_ang")
carpeta_ref_sample2 = os.path.join(ruta_actual,"src\\reference2")
archivos_dat_ref = glob(os.path.join(os.path.join(carpeta_ref_sample2,'carpeta1'), '*.dat'))
archivos_dat_samp = glob(os.path.join(os.path.join(carpeta_sample2,'carpeta1'), '*.dat'))

# Elimina cada archivo
for archivo in archivos_dat_samp:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

for archivo in archivos_dat_ref:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

convert_dats(carpeta_ref_sample2,1)
convert_dats(carpeta_sample2,5)

# Filtrar y ordenar los archivos por la temperatura
archivos_dat_ref = sorted(
    archivos_dat_ref,
    key=lambda x: extraer_temperatura(x)
)

archivos_dat_samp = sorted(
    archivos_dat_samp,
    key=lambda x: extraer_temperatura(x)
)
# Out:
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_12.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_124.0K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_147.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_170.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_192.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_213.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_234.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_24.7K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_255.75K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_68.1K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_98.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\reference2\carpeta1\Average_294.05K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\reference2\carpeta1\Average_294.05K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\reference2\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_12.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_24.7K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_68.1K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_98.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_124.0K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_147.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_170.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_192.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_213.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_234.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1\Average_255.75K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\Materials\analisis_datos_rapido\src\sample2_ang\carpeta1.

# %%
from matplotlib import pyplot as plt
from matplotlib import gridspec
from ipywidgets import interact, FloatSlider
import numpy as np
import pandas as pd
import scipy as sp

def anim3(left, right_sample, right_subs, index, desv, d):
    right_ref = right_subs
    N = 2**15

    f = plt.figure(figsize=(10, 8), dpi=200)  # Aumenté el tamaño para 3 subplots

    # Grid: 2 filas, 2 columnas (la última celda ocupará ambas columnas)
    gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

    # Subgráficos
    ax1 = plt.subplot(gs[0, 0])  # Señales temporales (original)
    ax2 = plt.subplot(gs[0, 1])  # FFTs (nuevo)
    ax3 = plt.subplot(gs[1, :])  # Absorción (ocupa toda la fila inferior)

    # Ruta del archivo de señal y de referencia
    path_signal = archivos_dat_samp[int(index)]
    path_ref = archivos_dat_ref[0]

    # Ventana y señales procesadas
    params_window1 = ['gaussian', desv]
    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1
    )

    # Aplicar ventana
    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2  # Desplazamiento para visualización

    # Señales en dominio temporal (subplot 1)
    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'r', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val,'b', label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title("Time Domain Signals")
    ax1.legend(loc='lower right')

    # Dominio de frecuencia
    nu = sp.fft.fftfreq(N, 1/30)
    k = 15
    nu = nu[1:len(nu)//k]

    # Aplicar Fourier y truncar
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)+1]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)+1]

    # Máscara de frecuencia
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)
    nu_filtradas = nu[mask]
    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]

    # Subplot 2: FFTs
    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2/np.abs(max(np.abs(fft_y_signal_ventaneada)**2)),'b', label='Sample FFT')
    ax2.plot(nu_filtradas, np.abs(fft_y_subs_ventaneada)**2/np.abs(max(np.abs(fft_y_subs_ventaneada)**2)),'r', label='Reference FFT')
    ax2.set_title("Frequency Domain")
    ax2.set_ylabel("$|FFT|^{2}$")
    ax2.set_xlabel(r"$\nu$ (THz)")
    ax2.legend()

    # Transmitancia y fase
    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase / 30)
    
    # Subplot 3: Absorción (ocupa toda la fila inferior)
    ax3.plot(nu_filtradas, -2 / d * np.log(abs(T)),'b')
    ax3.set_ylabel(r"$\alpha$")
    ax3.set_xlabel(r"$\nu$ (THz)")
    ax3.set_title("Absorption Spectrum")
    # ax3.set_yscale('log')  # Descomenta si quieres escala logarítmica

    plt.tight_layout()

# Interfaz interactiva (sin cambios)
opc = dict(continuous_update=False, readout_format=".3f")
interact(anim3,       
    left=FloatSlider(min=40, max=70, value=53, step=0.1, **opc),
    right_sample=FloatSlider(min=50, max=70, value=63.5, step=0.1, **opc),
    right_subs=FloatSlider(min=50, max=70, value=63.5, step=0.1, **opc),
    index=FloatSlider(min=0, max=len(archivos_dat_samp) - 1, value=0, step=1, **opc),
    desv=FloatSlider(min=0, max=1000, value=150, step=0.001, **opc),
    d=FloatSlider(min=0.01, max=1, value=0.627, step=0.01, **opc)
)
# Out:
# interactive(children=(FloatSlider(value=53.0, continuous_update=False, description='left', max=70.0, min=40.0,…
# <function __main__.anim3(left, right_sample, right_subs, index, desv, d)>

# %%
import matplotlib.animation as animation
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from colorsys import hsv_to_rgb
import matplotlib.cm as cm
from matplotlib.colors import Normalize


def create_frame(index, left, right_sample, right_subs, desv, d, axes, norm, cmap):
    ax1, ax2 = axes

    # Limpiar los ejes en lugar de fig.clear()
    for ax in axes:
        ax.clear()

    path_signal = archivos_dat_samp[int(index)]
    temp = extraer_temperatura(path_signal)
    color = cmap(norm(temp)) if temp is not None else 'blue'
    path_ref = archivos_dat_ref[0]

    N = 2**15
    params_window1 = ['gaussian', desv]

    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1)

    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2

    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'k', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val, color=color, label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title(f"T = {temp} K" if temp is not None else "Temperatura no disponible")
    ax1.legend(loc='lower right')

    k = 15
    nu = sp.fft.fftfreq(N, 1 / 30)
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

    nu = nu[1:len(nu)//k]
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)

    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
    nu_filtradas = nu[mask]

    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase * 1 / 30)

    T_exp = abs(T)
    phi_exp = np.unwrap(np.angle(T))

    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2, color=color)
    
    ax2.set_ylabel(r"$|FFT|^2$")
    # ax2.set_yscale('log')

def generate_gif():
    temps = []
    for path in archivos_dat_samp:
        temp = extraer_temperatura(path)
        if temp is not None:
            temps.append(temp)

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    left = 53.3
    right_sample = 70
    right_subs = 70.5
    desv = 158.0
    d = 0.627

    fig = plt.figure(figsize=(8, 4), dpi=200)
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])
    ax1 = plt.subplot(gs[0, 0])
    ax2 = plt.subplot(gs[0, 1])

  
    axes = [ax1, ax2]

    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    def animate(i):
        create_frame(i, left, right_sample, right_subs, desv, d, axes, norm, cmap)
        return axes
    carpeta = os.getcwd()
    ruta_guardado = os.path.join(carpeta, 'animacion_datos180_gaus.gif')
    ani = animation.FuncAnimation(fig, animate, frames=len(archivos_dat_samp)-1, interval=400, blit=False)
    ani.save(ruta_guardado, writer=animation.PillowWriter(fps=2), dpi=200)
    plt.close()

# Ejecutar
generate_gif()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from matplotlib import cm
from matplotlib.colors import Normalize
import os

def plot_all_samples(left, right_sample, right_subs, desv, d, val_offset_signal=2, val_offset_kappa=0.03):
    temps = [extraer_temperatura(p) for p in archivos_dat_samp if extraer_temperatura(p) is not None][::-1]

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    N = 2**15
    params_window1 = ['gaussian', desv]
    fig, (ax1, ax4) = plt.subplots(1, 2, figsize=(8, 8), dpi=200)

    # ax1.set_title("Señal ventaneada + ventana (todas las muestras)")
    ax1.set_ylabel("Normalized field + offset")
    ax1.set_xlabel("Time (arb. u.)")

    # ax4.set_title(r"Coeficiente de extinción $\kappa$ (todas las muestras)")
    ax4.set_xlabel(r"$\nu$ (THz)")
    ax4.set_ylabel(r"$|FFT|^{2}$ (arb. u.)")

    # Antes del bucle, creamos listas para almacenar los máximos
    max1_freqs = []
    max1_values = []
    max2_freqs = []
    max2_values = []

    for index, path_signal in enumerate(archivos_dat_samp):
        temp = temps[index]
        color = cmap(norm(temp)) if temp is not None else 'blue'
        path_ref = archivos_dat_ref[0]

        phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
            path_signal, path_ref, left, right_sample, right_subs, params_window1)

        y_subs_ventana = pd.Series(y_substrate_padding * ventana)
        y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

        offset_signal = val_offset_signal * index

        ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + offset_signal, color=color, label=f'{temp:.1f} K')

        # FFT y kappa
        k = 15
        nu = sp.fft.fftfreq(N, 1 / 30)
        fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
        fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

        nu = nu[1:len(nu)//k]
        xmin, xmax = 0.3, 1.0
        mask = (nu >= xmin) & (nu <= xmax)

        fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
        fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
        nu_filtradas = nu[mask]

        val_offset_kappa = 0.8
        offset_kappa = val_offset_kappa * index
        
        normalized_fft = np.abs(fft_y_signal_ventaneada)**2/np.max(np.abs(fft_y_signal_ventaneada)**2) + offset_kappa
        
        ax4.plot(nu_filtradas, normalized_fft, color=color, label=f'{temp:.1f} K')
        
        max1_idx = np.argmax(normalized_fft)
        max1_freq = nu_filtradas[max1_idx]
        max1_val = normalized_fft[max1_idx]
                
            # Segundo máximo (entre 0.7 y 0.9 THz)
        mask_second_peak = (nu_filtradas >= 0.38) & (nu_filtradas <= 0.45)
        if np.any(mask_second_peak):  # Verificamos que haya datos en este rango
            second_peak_region = normalized_fft[mask_second_peak]
            second_peak_nu = nu_filtradas[mask_second_peak]
            max2_idx = np.argmax(second_peak_region)
            max2_freq = second_peak_nu[max2_idx]
            max2_val = second_peak_region[max2_idx]
        else:
            max2_freq, max2_val = np.nan, np.nan
        
        # Guardamos los máximos
        max1_freqs.append(max1_freq)
        max1_values.append(max1_val)
        max2_freqs.append(max2_freq)
        max2_values.append(max2_val)
        
        # Graficamos ambos puntos máximos
        ax4.scatter(max1_freq, max1_val, color='black', edgecolors=color, s=50, zorder=5)
        if not np.isnan(max2_freq):  # Solo graficar si existe el segundo máximo
            ax4.scatter(max2_freq, max2_val, color='white', edgecolors=color, s=50, zorder=5, marker='s')
        
        print(temp)
        # Después del bucle, unimos los puntos máximos con líneas
    ax4.plot(max1_freqs, max1_values, 'k--', linewidth=1, alpha=0.5, label='1er máximo')
    if any(not np.isnan(f) for f in max2_freqs):  # Solo graficar si hay segundos máximos
        ax4.plot(max2_freqs, max2_values, 'k:', linewidth=1, alpha=0.5, label='2do máximo')
    ax1.legend(loc='upper right', fontsize='small')
    # ax4.legend(loc='upper left', fontsize='small')

    # Barra de temperatura al costado
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    # plt.show()

        # Crear nueva figura para frecuencia vs temperatura
    fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(4, 8), dpi=200)

    # Graficar primer máximo (principal)
    ax1.scatter(temps[:-1], max1_freqs[:-1], c=temps[:-1], cmap='coolwarm', 
                edgecolors='k', s=80, label='Main peak', zorder=3)
    ax1.legend(loc='upper right', fontsize='small')
    ax1.plot(temps[:-1], max1_freqs[:-1], 'k--', alpha=0.3, linewidth=1)

    # Graficar segundo máximo (secundario, solo si existen valores válidos)
    valid_max2 = [(t, f) for t, f in zip(temps, max2_freqs) if not np.isnan(f)]
    if valid_max2:
        temps_max2, freqs_max2 = zip(*valid_max2)
        ax2.scatter(temps_max2[:-1], freqs_max2[:-1], c=temps_max2[:-1], cmap='coolwarm', 
                    edgecolors='k', s=80, marker='s', label='Secondary peak', zorder=3)
        ax2.set_xlabel('Temperature (K)')
        ax2.legend(loc='upper right', fontsize='small')
        ax2.set_ylabel('Frecuency (THz)')
    if valid_max2:
        ax2.plot(temps_max2[:-1] ,freqs_max2[:-1], 'k:', alpha=0.3, linewidth=1)

    # Añadir líneas de tendencia (opcional)
    # ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)
    # if valid_max2:
    #     ax1.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Ajustes estéticos
    # ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel('Frecuency (THz)')
    # ax1.title('Frecuencia de máximos vs Temperatura', fontsize=14)
    # ax1.grid(True, alpha=0.3)


# Ejecutar la función
plot_all_samples(left=57.0, right_sample=65.5, right_subs=65, desv=170.0, d=0.627)
# Out:
# 255.75
# 234.4
# 213.6
# 192.4
# 170.5
# 147.8
# 124.0
# 98.3
# 68.1
# 24.7
# 12.2

# %% [markdown]
# # Sample3

# %%
# sample1_ang_csv = os.path.join(ruta_actual,"sample1_ang.csv")
carpeta_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\sample3_ang")
carpeta_ref_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\reference3")
archivos_dat_ref = glob(os.path.join(os.path.join(carpeta_ref_sample1,'carpeta1'), '*.dat'))
archivos_dat_samp = glob(os.path.join(os.path.join(carpeta_sample1,'carpeta1'), '*.dat'))

# Elimina cada archivo
for archivo in archivos_dat_samp:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

for archivo in archivos_dat_ref:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

convert_dats(carpeta_ref_sample1,1)
convert_dats(carpeta_sample1,3)

# Filtrar y ordenar los archivos por la temperatura
archivos_dat_ref = sorted(
    archivos_dat_ref,
    key=lambda x: extraer_temperatura(x)
)

archivos_dat_samp = sorted(
    archivos_dat_samp,
    key=lambda x: extraer_temperatura(x)
)
# Out:
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_101.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_105.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_109.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_114.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_118.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_122.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_126.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_130.7K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_134.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_138.7K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_142.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_24.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_33.1K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_39.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_45.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_51.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_56.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_61.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_66.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_70.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_75.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_79.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_84.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_88.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_9.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_92.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_97.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference3\carpeta1\Average_294.05K.dat eliminado.
# ['20250613-104042__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.1K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250613-104419__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.0K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250613-104757__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.0K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat']
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference3\carpeta1\Average_294.05K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference3\carpeta1.
# ['20250616-143900__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__9.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-144538__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__24.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-145214__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__33.1K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-145851__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__39.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-150529__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__45.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-151207__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__51.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-151846__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__56.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-152524__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__61.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-153201__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__66.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-153838__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__70.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-154516__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__75.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-155154__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__79.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-155833__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__84.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-160510__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__88.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-161148__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__92.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-161826__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__97.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-162504__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__101.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-163142__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__105.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-163819__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__109.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-164457__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__114.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-165135__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__118.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-165813__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__122.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-170450__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__126.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-171128__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__130.7K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-171805__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__134.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-172442__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__138.7K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat', '20250616-172455__Eduardo__THZ58.5-69.5__PMP0__S2207L__7RH__142.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient225-HePumpON-100ms-long.dat']
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_9.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_24.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_33.1K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_39.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_45.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_51.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_56.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_61.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_66.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_70.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_75.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_79.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_84.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_88.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_92.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_97.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_101.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_105.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_109.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_114.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_118.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_122.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_126.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_130.7K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_134.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_138.7K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1\Average_142.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample3_ang\carpeta1.

# %%
archivos_dat_ref
# Out:
# ['c:\\Users\\esteb\\Escritorio\\physics\\mestrado_thz_physics\\EuZn2P2\\src\\reference3\\carpeta1\\Average_294.05K.dat']

# %%
from matplotlib import pyplot as plt
from matplotlib import gridspec
from ipywidgets import interact, FloatSlider
import numpy as np
import pandas as pd
import scipy as sp

def anim2(left, right_sample, right_subs, index, desv, d):
    right_ref = right_subs
    N = 2**15

    f = plt.figure(figsize=(10, 8), dpi=200)  # Aumenté el tamaño para 3 subplots

    # Grid: 2 filas, 2 columnas (la última celda ocupará ambas columnas)
    gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

    # Subgráficos
    ax1 = plt.subplot(gs[0, 0])  # Señales temporales (original)
    ax2 = plt.subplot(gs[0, 1])  # FFTs (nuevo)
    ax3 = plt.subplot(gs[1, :])  # Absorción (ocupa toda la fila inferior)

    # Ruta del archivo de señal y de referencia
    path_signal = archivos_dat_samp[int(index)]
    path_ref = archivos_dat_ref[0]

    # Ventana y señales procesadas
    params_window1 = ['gaussian',desv]
    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1
    )

    # Aplicar ventana
    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2  # Desplazamiento para visualización

    # Señales en dominio temporal (subplot 1)
    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'r', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val,'b', label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title("Time Domain Signals")
    ax1.legend(loc='lower right')

    # Dominio de frecuencia
    nu = sp.fft.fftfreq(N, 1/30)
    k = 15
    nu = nu[1:len(nu)//k]

    # Aplicar Fourier y truncar
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)+1]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)+1]

    # Máscara de frecuencia
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)
    nu_filtradas = nu[mask]
    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]

    # Subplot 2: FFTs
    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2/np.abs(max(np.abs(fft_y_signal_ventaneada)**2)),'b', label='Sample FFT')
    ax2.plot(nu_filtradas, np.abs(fft_y_subs_ventaneada)**2/np.abs(max(np.abs(fft_y_subs_ventaneada)**2)),'r', label='Reference FFT')
    ax2.set_title("Frequency Domain")
    ax2.set_ylabel("$|FFT|^{2}$")
    ax2.set_xlabel(r"$\nu$ (THz)")
    ax2.legend()

    # Transmitancia y fase
    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase / 30)
    
    # Subplot 3: Absorción (ocupa toda la fila inferior)
    ax3.plot(nu_filtradas, -2 / d * np.log(abs(T)),'b')
    ax3.set_ylabel(r"$\alpha$")
    ax3.set_xlabel(r"$\nu$ (THz)")
    ax3.set_title("Absorption Spectrum")
    # ax3.set_yscale('log')  # Descomenta si quieres escala logarítmica

    plt.tight_layout()

# Interfaz interactiva (sin cambios)
opc = dict(continuous_update=False, readout_format=".3f")
interact(anim2,       
    left=FloatSlider(min=380, max=423, value=394.9, step=0.1, **opc),
    right_sample=FloatSlider(min=380, max=450, value=417.9, step=0.1, **opc),
    right_subs=FloatSlider(min=380, max=450, value=417.9, step=0.1, **opc),
    index=FloatSlider(min=0, max=len(archivos_dat_samp) - 1, value=0, step=1, **opc),
    desv=FloatSlider(min=0, max=1000, value=190.324, step=0.001, **opc),
    d=FloatSlider(min=0.01, max=1, value=0.627, step=0.01, **opc)
)
# Out:
# interactive(children=(FloatSlider(value=394.9, continuous_update=False, description='left', max=423.0, min=380…
# <function __main__.anim2(left, right_sample, right_subs, index, desv, d)>

# %%
import matplotlib.animation as animation
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from colorsys import hsv_to_rgb
import matplotlib.cm as cm
from matplotlib.colors import Normalize


def create_frame(index, left, right_sample, right_subs, desv, d, axes, norm, cmap):
    ax1, ax2 = axes

    # Limpiar los ejes en lugar de fig.clear()
    for ax in axes:
        ax.clear()

    path_signal = archivos_dat_samp[int(index)]
    temp = extraer_temperatura(path_signal)
    color = cmap(norm(temp)) if temp is not None else 'blue'
    path_ref = archivos_dat_ref[0]

    N = 2**15
    params_window1 = ['flattop']

    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1)

    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2

    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'k', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val, color=color, label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title(f"T = {temp} K" if temp is not None else "Temperatura no disponible")
    ax1.legend(loc='lower right')

    k = 15
    nu = sp.fft.fftfreq(N, 1 / 30)
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

    nu = nu[1:len(nu)//k]
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)

    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
    nu_filtradas = nu[mask]

    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase * 1 / 30)

    T_exp = abs(T)
    phi_exp = np.unwrap(np.angle(T))

    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2, color=color)
    
    ax2.set_ylabel(r"$|FFT|^2$")
    # ax2.set_yscale('log')

def generate_gif():
    temps = []
    for path in archivos_dat_samp:
        temp = extraer_temperatura(path)
        if temp is not None:
            temps.append(temp)

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    left = 398
    right_sample = 435.4
    right_subs = 423
    desv = 190.324
    d = 0.627

    fig = plt.figure(figsize=(8, 4), dpi=200)
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])
    ax1 = plt.subplot(gs[0, 0])
    ax2 = plt.subplot(gs[0, 1])

  
    axes = [ax1, ax2]

    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    def animate(i):
        create_frame(i, left, right_sample, right_subs, desv, d, axes, norm, cmap)
        return axes
    carpeta = os.getcwd()
    ruta_guardado = os.path.join(carpeta, 'animacion_datos225_flattop.gif')
    ani = animation.FuncAnimation(fig, animate, frames=len(archivos_dat_samp), interval=400, blit=False)
    ani.save(ruta_guardado, writer=animation.PillowWriter(fps=2), dpi=200)
    plt.close()

# Ejecutar
generate_gif()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from matplotlib import cm
from matplotlib.colors import Normalize
import os

def plot_all_samples(left, right_sample, right_subs, desv, d, val_offset_signal=2, val_offset_kappa=0.03):
    temps = [extraer_temperatura(p) for p in archivos_dat_samp if extraer_temperatura(p) is not None][::-1]

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    N = 2**15
    params_window1 = ['flattop']
    fig, (ax1, ax4) = plt.subplots(1, 2, figsize=(8, 8), dpi=200)

    # ax1.set_title("Señal ventaneada + ventana (todas las muestras)")
    ax1.set_ylabel("Normalized field + offset")
    ax1.set_xlabel("Time (arb. u.)")

    # ax4.set_title(r"Coeficiente de extinción $\kappa$ (todas las muestras)")
    ax4.set_xlabel(r"$\nu$ (THz)")
    ax4.set_ylabel(r"$|FFT|^{2}$ (arb. u.)")

    # Antes del bucle, creamos listas para almacenar los máximos
    max1_freqs = []
    max1_values = []
    max2_freqs = []
    max2_values = []

    for index, path_signal in enumerate(archivos_dat_samp):
        temp = temps[index]
        color = cmap(norm(temp)) if temp is not None else 'blue'
        path_ref = archivos_dat_ref[0]

        phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
            path_signal, path_ref, left, right_sample, right_subs, params_window1)

        y_subs_ventana = pd.Series(y_substrate_padding * ventana)
        y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

        offset_signal = val_offset_signal * index

        ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + offset_signal, color=color, label=f'{temp:.1f} K')

        # FFT y kappa
        k = 15
        nu = sp.fft.fftfreq(N, 1 / 30)
        fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
        fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

        nu = nu[1:len(nu)//k]
        xmin, xmax = 0.3, 1.0
        mask = (nu >= xmin) & (nu <= xmax)

        fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
        fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
        nu_filtradas = nu[mask]

        val_offset_kappa = 0.8
        offset_kappa = val_offset_kappa * index
        
        normalized_fft = np.abs(fft_y_signal_ventaneada)**2/np.max(np.abs(fft_y_signal_ventaneada)**2) + offset_kappa
        
        ax4.plot(nu_filtradas, normalized_fft, color=color, label=f'{temp:.1f} K')
        
        max1_idx = np.argmax(normalized_fft)
        max1_freq = nu_filtradas[max1_idx]
        max1_val = normalized_fft[max1_idx]
                
            # Segundo máximo (entre 0.7 y 0.9 THz)
        mask_second_peak = (nu_filtradas >= 0.8) & (nu_filtradas <= 0.9)
        if np.any(mask_second_peak):  # Verificamos que haya datos en este rango
            second_peak_region = normalized_fft[mask_second_peak]
            second_peak_nu = nu_filtradas[mask_second_peak]
            max2_idx = np.argmax(second_peak_region)
            max2_freq = second_peak_nu[max2_idx]
            max2_val = second_peak_region[max2_idx]
        else:
            max2_freq, max2_val = np.nan, np.nan
        
        # Guardamos los máximos
        max1_freqs.append(max1_freq)
        max1_values.append(max1_val)
        max2_freqs.append(max2_freq)
        max2_values.append(max2_val)
        
        # Graficamos ambos puntos máximos
        ax4.scatter(max1_freq, max1_val, color='black', edgecolors=color, s=50, zorder=5)
        if not np.isnan(max2_freq):  # Solo graficar si existe el segundo máximo
            ax4.scatter(max2_freq, max2_val, color='white', edgecolors=color, s=50, zorder=5, marker='s')
        
        print(temp)
        # Después del bucle, unimos los puntos máximos con líneas
    ax4.plot(max1_freqs, max1_values, 'k--', linewidth=1, alpha=0.5, label='1er máximo')
    if any(not np.isnan(f) for f in max2_freqs):  # Solo graficar si hay segundos máximos
        ax4.plot(max2_freqs, max2_values, 'k:', linewidth=1, alpha=0.5, label='2do máximo')
    ax1.legend(loc='upper left', fontsize='small')
    # ax4.legend(loc='upper left', fontsize='small')

    # Barra de temperatura al costado
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    # plt.show()

        # Crear nueva figura para frecuencia vs temperatura
    fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(4, 8), dpi=200)

    # Graficar primer máximo (principal)
    ax1.scatter(temps, max1_freqs, c=temps, cmap='coolwarm', 
                edgecolors='k', s=80, label='Main peak', zorder=3)
    ax1.legend(loc='upper left', fontsize='small')
    ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)

    # Graficar segundo máximo (secundario, solo si existen valores válidos)
    valid_max2 = [(t, f) for t, f in zip(temps, max2_freqs) if not np.isnan(f)]
    if valid_max2:
        temps_max2, freqs_max2 = zip(*valid_max2)
        ax2.scatter(temps_max2, freqs_max2, c=temps_max2, cmap='coolwarm', 
                    edgecolors='k', s=80, marker='s', label='Secondary peak', zorder=3)
        ax2.set_xlabel('Temperature (K)')
        ax2.legend(loc='upper left', fontsize='small')
        ax2.set_ylabel('Frecuency (THz)')
    if valid_max2:
        ax2.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Añadir líneas de tendencia (opcional)
    # ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)
    # if valid_max2:
    #     ax1.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Ajustes estéticos
    # ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel('Frecuency (THz)')
    # ax1.title('Frecuencia de máximos vs Temperatura', fontsize=14)
    # ax1.grid(True, alpha=0.3)


# Ejecutar la función
plot_all_samples(left=398.0, right_sample=435.4, right_subs=423, desv=190.324, d=0.627)
# Out:
# 142.8
# 138.7
# 134.8
# 130.7
# 126.6
# 122.5
# 118.3
# 114.2
# 109.9
# 105.8
# 101.5
# 97.2
# 92.9
# 88.6
# 84.2
# 79.8
# 75.3
# 70.8
# 66.2
# 61.5
# 56.6
# 51.4
# 45.8
# 39.9
# 33.1
# 24.8
# 9.4

# %% [markdown]
# # SAMPLE 4

# %%
# sample1_ang_csv = os.path.join(ruta_actual,"sample1_ang.csv")
carpeta_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\sample4_ang")
carpeta_ref_sample1 = os.path.join(ruta_actual,"EuZn2P2\\src\\reference4")
archivos_dat_ref = glob(os.path.join(os.path.join(carpeta_ref_sample1,'carpeta1'), '*.dat'))
archivos_dat_samp = glob(os.path.join(os.path.join(carpeta_sample1,'carpeta1'), '*.dat'))

# Elimina cada archivo
for archivo in archivos_dat_samp:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

for archivo in archivos_dat_ref:
    os.remove(archivo)
    print(f'Archivo {archivo} eliminado.')

convert_dats(carpeta_ref_sample1,1)
convert_dats(carpeta_sample1,3)

# Filtrar y ordenar los archivos por la temperatura
archivos_dat_ref = sorted(
    archivos_dat_ref,
    key=lambda x: extraer_temperatura(x)
)

archivos_dat_samp = sorted(
    archivos_dat_samp,
    key=lambda x: extraer_temperatura(x)
)
# Out:
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_10.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_100.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_104.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_108.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_113.1K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_117.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_121.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_125.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_129.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_133.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_137.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_141.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_145.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_148.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_152.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_156.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_160.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_163.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_167.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_171.0K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_25.5K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_33.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_39.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_45.8K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_51.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_56.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_61.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_65.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_70.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_74.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_79.3K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_83.6K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_87.9K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_92.2K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_96.4K.dat eliminado.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference4\carpeta1\Average_294.05K.dat eliminado.
# ['20250613-104042__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.1K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250613-104419__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.0K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat', '20250613-104757__Eduardo__THZ57.5-63.5__PMP0__S2207L__6RH__294.0K__PTFEwindows+1.5mmHole+air__Hpol-reference-HePumpOFF-100ms.dat']
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference4\carpeta1\Average_294.05K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\reference4\carpeta1.
# ['20250617-123409__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__10.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-124046__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__25.5K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-124723__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__33.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-125400__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__39.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-130038__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__45.8K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-130715__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__51.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-131353__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__56.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-132030__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__61.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-132708__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__65.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-133345__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__70.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-134023__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__74.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-134700__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__79.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-135338__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__83.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-140016__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__87.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-140653__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__92.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-141332__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__96.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-142009__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__100.6K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-142647__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__104.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-143325__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__108.9K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-144003__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__113.1K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-144640__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__117.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-145318__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__121.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-145956__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__125.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-150633__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__129.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-151311__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__133.4K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-151949__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__137.3K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-long.dat', '20250617-152627__Eduardo__THZ58.5-69.5__PMP0__S2207L__5RH__141.2K__PTFEwindows+1.5mmHole+EuZn2P2__Hpol-0.627mm-orient270-HePumpOFF-100ms-lon ...
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_10.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_25.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_33.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_39.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_45.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_51.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_56.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_61.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_65.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_70.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_74.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_79.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_83.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_87.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_92.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_96.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_100.6K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_104.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_108.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_113.1K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_117.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_121.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_125.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_129.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_133.4K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_137.3K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_141.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_145.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_148.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_152.8K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_156.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_160.2K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_163.9K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_167.5K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.
# Archivo c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1\Average_171.0K.dat generado en c:\Users\esteb\Escritorio\physics\mestrado_thz_physics\EuZn2P2\src\sample4_ang\carpeta1.

# %%
archivos_dat_ref
# Out:
# ['c:\\Users\\esteb\\Escritorio\\physics\\mestrado_thz_physics\\EuZn2P2\\src\\reference4\\carpeta1\\Average_294.05K.dat']

# %%
from matplotlib import pyplot as plt
from matplotlib import gridspec
from ipywidgets import interact, FloatSlider
import numpy as np
import pandas as pd
import scipy as sp

def anim2(left, right_sample, right_subs, index, desv, d):
    right_ref = right_subs
    N = 2**15

    f = plt.figure(figsize=(10, 8), dpi=200)  # Aumenté el tamaño para 3 subplots

    # Grid: 2 filas, 2 columnas (la última celda ocupará ambas columnas)
    gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

    # Subgráficos
    ax1 = plt.subplot(gs[0, 0])  # Señales temporales (original)
    ax2 = plt.subplot(gs[0, 1])  # FFTs (nuevo)
    ax3 = plt.subplot(gs[1, :])  # Absorción (ocupa toda la fila inferior)

    # Ruta del archivo de señal y de referencia
    path_signal = archivos_dat_samp[int(index)]
    path_ref = archivos_dat_ref[0]

    # Ventana y señales procesadas
    params_window1 = ['flattop']
    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1
    )

    # Aplicar ventana
    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2  # Desplazamiento para visualización

    # Señales en dominio temporal (subplot 1)
    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'r', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val,'b', label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title("Time Domain Signals")
    ax1.legend(loc='lower right')

    # Dominio de frecuencia
    nu = sp.fft.fftfreq(N, 1/30)
    k = 15
    nu = nu[1:len(nu)//k]

    # Aplicar Fourier y truncar
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)+1]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)+1]

    # Máscara de frecuencia
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)
    nu_filtradas = nu[mask]
    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]

    # Subplot 2: FFTs
    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2/np.abs(max(np.abs(fft_y_signal_ventaneada)**2)),'b', label='Sample FFT')
    ax2.plot(nu_filtradas, np.abs(fft_y_subs_ventaneada)**2/np.abs(max(np.abs(fft_y_subs_ventaneada)**2)),'r', label='Reference FFT')
    ax2.set_title("Frequency Domain")
    ax2.set_ylabel("$|FFT|^{2}$")
    ax2.set_xlabel(r"$\nu$ (THz)")
    ax2.legend()

    # Transmitancia y fase
    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase / 30)
    
    # Subplot 3: Absorción (ocupa toda la fila inferior)
    ax3.plot(nu_filtradas, -2 / d * np.log(abs(T)),'b')
    ax3.set_ylabel(r"$\alpha$")
    ax3.set_xlabel(r"$\nu$ (THz)")
    ax3.set_title("Absorption Spectrum")
    # ax3.set_yscale('log')  # Descomenta si quieres escala logarítmica

    plt.tight_layout()

# Interfaz interactiva (sin cambios)
opc = dict(continuous_update=False, readout_format=".3f")
interact(anim2,       
    left=FloatSlider(min=380, max=423, value=394.9, step=0.1, **opc),
    right_sample=FloatSlider(min=380, max=450, value=417.9, step=0.1, **opc),
    right_subs=FloatSlider(min=380, max=450, value=417.9, step=0.1, **opc),
    index=FloatSlider(min=0, max=len(archivos_dat_samp) - 1, value=0, step=1, **opc),
    desv=FloatSlider(min=0, max=1000, value=190.324, step=0.001, **opc),
    d=FloatSlider(min=0.01, max=1, value=0.627, step=0.01, **opc)
)
# Out:
# interactive(children=(FloatSlider(value=394.9, continuous_update=False, description='left', max=423.0, min=380…
# <function __main__.anim2(left, right_sample, right_subs, index, desv, d)>

# %%
import matplotlib.animation as animation
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from colorsys import hsv_to_rgb
import matplotlib.cm as cm
from matplotlib.colors import Normalize


def create_frame(index, left, right_sample, right_subs, desv, d, axes, norm, cmap):
    ax1, ax2 = axes

    # Limpiar los ejes en lugar de fig.clear()
    for ax in axes:
        ax.clear()

    path_signal = archivos_dat_samp[int(index)]
    temp = extraer_temperatura(path_signal)
    color = cmap(norm(temp)) if temp is not None else 'blue'
    path_ref = archivos_dat_ref[0]

    N = 2**15
    params_window1 = ['flattop']

    phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
        path_signal, path_ref, left, right_sample, right_subs, params_window1)

    y_subs_ventana = pd.Series(y_substrate_padding * ventana)
    y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

    val = 2

    ax1.plot(y_subs_ventana / max(y_subs_ventana), 'k', label='Ref')
    ax1.plot(ventana / max(ventana), 'k--', label='Window')
    ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + val, color=color, label=f'Sam+{extraer_temperatura(path_signal)} K')
    ax1.plot(ventana / max(ventana) + val, 'k--')
    # ax1.set_title(f"T = {temp} K" if temp is not None else "Temperatura no disponible")
    ax1.legend(loc='lower right')

    k = 15
    nu = sp.fft.fftfreq(N, 1 / 30)
    fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
    fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

    nu = nu[1:len(nu)//k]
    xmin, xmax = 0.2, 1.0
    mask = (nu >= xmin) & (nu <= xmax)

    fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
    fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
    nu_filtradas = nu[mask]

    T = fft_y_signal_ventaneada / fft_y_subs_ventaneada * np.exp(-1j * 2 * np.pi * nu_filtradas * phase * 1 / 30)

    T_exp = abs(T)
    phi_exp = np.unwrap(np.angle(T))

    ax2.plot(nu_filtradas, np.abs(fft_y_signal_ventaneada)**2, color=color)
    
    ax2.set_ylabel(r"$|FFT|^2$")
    # ax2.set_yscale('log')

def generate_gif():
    temps = []
    for path in archivos_dat_samp:
        temp = extraer_temperatura(path)
        if temp is not None:
            temps.append(temp)

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    left = 397.3
    right_sample = 432.60
    right_subs = 428.1
    desv = 190.324
    d = 0.627

    fig = plt.figure(figsize=(8, 4), dpi=200)
    gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])
    ax1 = plt.subplot(gs[0, 0])
    ax2 = plt.subplot(gs[0, 1])

  
    axes = [ax1, ax2]

    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    def animate(i):
        create_frame(i, left, right_sample, right_subs, desv, d, axes, norm, cmap)
        return axes
    carpeta = os.getcwd()
    ruta_guardado = os.path.join(carpeta, 'animacion_datos225.gif')
    ani = animation.FuncAnimation(fig, animate, frames=len(archivos_dat_samp), interval=400, blit=False)
    ani.save(ruta_guardado, writer=animation.PillowWriter(fps=2), dpi=200)
    plt.close()

# Ejecutar
generate_gif()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from matplotlib import cm
from matplotlib.colors import Normalize
import os

def plot_all_samples(left, right_sample, right_subs, desv, d, val_offset_signal=2, val_offset_kappa=0.03):
    temps = [extraer_temperatura(p) for p in archivos_dat_samp if extraer_temperatura(p) is not None][::-1]

    if not temps:
        raise ValueError("No se encontraron temperaturas válidas en los archivos")

    min_temp, max_temp = min(temps), max(temps)
    norm = Normalize(vmin=min_temp, vmax=max_temp)
    cmap = cm.coolwarm

    N = 2**15
    params_window1 = ['flattop']
    fig, (ax1, ax4) = plt.subplots(1, 2, figsize=(8, 8), dpi=200)

    # ax1.set_title("Señal ventaneada + ventana (todas las muestras)")
    ax1.set_ylabel("Normalized field + offset")
    ax1.set_xlabel("Time (arb. u.)")

    # ax4.set_title(r"Coeficiente de extinción $\kappa$ (todas las muestras)")
    ax4.set_xlabel(r"$\nu$ (THz)")
    ax4.set_ylabel(r"$|FFT|^{2}$ (arb. u.)")

    # Antes del bucle, creamos listas para almacenar los máximos
    max1_freqs = []
    max1_values = []
    max2_freqs = []
    max2_values = []

    for index, path_signal in enumerate(archivos_dat_samp):
        temp = temps[index]
        color = cmap(norm(temp)) if temp is not None else 'blue'
        path_ref = archivos_dat_ref[0]

        phase, y_signal_ventaneada, y_substrate_padding, ventana = getSignalWindowed(
            path_signal, path_ref, left, right_sample, right_subs, params_window1)

        y_subs_ventana = pd.Series(y_substrate_padding * ventana)
        y_signal_ventaneada = pd.Series(y_signal_ventaneada * ventana)

        offset_signal = val_offset_signal * index

        ax1.plot(y_signal_ventaneada / max(y_signal_ventaneada) + offset_signal, color=color, label=f'{temp:.1f} K')

        # FFT y kappa
        k = 15
        nu = sp.fft.fftfreq(N, 1 / 30)
        fft_y_signal_ventaneada = FourierT2(y_signal_ventaneada, N)[1:len(nu)//k]
        fft_y_subs_ventaneada = FourierT2(y_subs_ventana, N)[1:len(nu)//k]

        nu = nu[1:len(nu)//k]
        xmin, xmax = 0.3, 1.0
        mask = (nu >= xmin) & (nu <= xmax)

        fft_y_signal_ventaneada = fft_y_signal_ventaneada[mask]
        fft_y_subs_ventaneada = fft_y_subs_ventaneada[mask]
        nu_filtradas = nu[mask]

        val_offset_kappa = 0.8
        offset_kappa = val_offset_kappa * index
        
        normalized_fft = np.abs(fft_y_signal_ventaneada)**2/np.max(np.abs(fft_y_signal_ventaneada)**2) + offset_kappa
        
        ax4.plot(nu_filtradas, normalized_fft, color=color, label=f'{temp:.1f} K')
        
        max1_idx = np.argmax(normalized_fft)
        max1_freq = nu_filtradas[max1_idx]
        max1_val = normalized_fft[max1_idx]
                
            # Segundo máximo (entre 0.7 y 0.9 THz)
        mask_second_peak = (nu_filtradas >= 0.8) & (nu_filtradas <= 0.9)
        if np.any(mask_second_peak):  # Verificamos que haya datos en este rango
            second_peak_region = normalized_fft[mask_second_peak]
            second_peak_nu = nu_filtradas[mask_second_peak]
            max2_idx = np.argmax(second_peak_region)
            max2_freq = second_peak_nu[max2_idx]
            max2_val = second_peak_region[max2_idx]
        else:
            max2_freq, max2_val = np.nan, np.nan
        
        # Guardamos los máximos
        max1_freqs.append(max1_freq)
        max1_values.append(max1_val)
        max2_freqs.append(max2_freq)
        max2_values.append(max2_val)
        
        # Graficamos ambos puntos máximos
        ax4.scatter(max1_freq, max1_val, color='black', edgecolors=color, s=50, zorder=5)
        if not np.isnan(max2_freq):  # Solo graficar si existe el segundo máximo
            ax4.scatter(max2_freq, max2_val, color='white', edgecolors=color, s=50, zorder=5, marker='s')
        
        print(temp)
        # Después del bucle, unimos los puntos máximos con líneas
    ax4.plot(max1_freqs, max1_values, 'k--', linewidth=1, alpha=0.5, label='1er máximo')
    if any(not np.isnan(f) for f in max2_freqs):  # Solo graficar si hay segundos máximos
        ax4.plot(max2_freqs, max2_values, 'k:', linewidth=1, alpha=0.5, label='2do máximo')
    ax1.legend(loc='upper left', fontsize='small')
    # ax4.legend(loc='upper left', fontsize='small')

    # Barra de temperatura al costado
    fig.subplots_adjust(right=0.85)
    cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    fig.colorbar(sm, cax=cbar_ax, label='Temperature (K)')

    # plt.show()

        # Crear nueva figura para frecuencia vs temperatura
    fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(4, 8), dpi=200)

    # Graficar primer máximo (principal)
    ax1.scatter(temps, max1_freqs, c=temps, cmap='coolwarm', 
                edgecolors='k', s=80, label='Main peak', zorder=3)
    ax1.legend(loc='upper left', fontsize='small')
    ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)

    # Graficar segundo máximo (secundario, solo si existen valores válidos)
    valid_max2 = [(t, f) for t, f in zip(temps, max2_freqs) if not np.isnan(f)]
    if valid_max2:
        temps_max2, freqs_max2 = zip(*valid_max2)
        ax2.scatter(temps_max2, freqs_max2, c=temps_max2, cmap='coolwarm', 
                    edgecolors='k', s=80, marker='s', label='Secondary peak', zorder=3)
        ax2.set_xlabel('Temperature (K)')
        ax2.legend(loc='upper left', fontsize='small')
        ax2.set_ylabel('Frecuency (THz)')
    if valid_max2:
        ax2.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Añadir líneas de tendencia (opcional)
    # ax1.plot(temps, max1_freqs, 'k--', alpha=0.3, linewidth=1)
    # if valid_max2:
    #     ax1.plot(temps_max2, freqs_max2, 'k:', alpha=0.3, linewidth=1)

    # Ajustes estéticos
    # ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel('Frecuency (THz)')
    # ax1.title('Frecuencia de máximos vs Temperatura', fontsize=14)
    # ax1.grid(True, alpha=0.3)


# Ejecutar la función
plot_all_samples(left=397.3, right_sample=432.60, right_subs=428.1, desv=190.324, d=0.627)
# Out:
# 171.0
# 167.5
# 163.9
# 160.2
# 156.5
# 152.8
# 148.9
# 145.2
# 141.2
# 137.3
# 133.4
# 129.3
# 125.4
# 121.2
# 117.2
# 113.1
# 108.9
# 104.9
# 100.6
# 96.4
# 92.2
# 87.9
# 83.6
# 79.3
# 74.9
# 70.4
# 65.9
# 61.3
# 56.4
# 51.3
# 45.8
# 39.9
# 33.4
# 25.5
# 10.2
